# %% [markdown]
# 1. What is a random variable in probability theory?
#  - A random variable is a numerical outcome of a random experiment. It maps the outcomes of a random process to real numbers.
#
# 2. What are the types of random variables?
#  - There are two main types:
#  - Discrete Random Variable: Takes countable values (e.g., number of students).
#  - Continuous Random Variable: Takes any value within a range (e.g., height, weight).
#
# 3. What is the difference between discrete and continuous distributions?
#  - Discrete Distribution: Deals with countable outcomes (e.g., binomial, Poisson).
#  - Continuous Distribution: Deals with infinite possible values within a range (e.g., normal, exponential).
#
# 4. What are probability distribution functions (PDF)?
#  - A PDF gives the probability of a random variable taking on a particular value. For continuous variables, it represents the density rather than exact probability.
#
# 5. How do cumulative distribution functions (CDF) differ from PDF?
#  - PDF shows the probability density at a specific value.
#  - CDF shows the probability that a variable is less than or equal to a certain value.
#
# 6. What is a discrete uniform distribution?
#  - A discrete uniform distribution assigns equal probability to a finite number of outcomes.
# Example: Rolling a fair die (each face has 1/6 probability).
#
# 7. What are the key properties of a Bernoulli distribution?
#  - Only two outcomes: success (1) or failure (0).
#
# One trial.
#
# Mean =
# 𝑝
# p, Variance =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p), where
# 𝑝
# p is the probability of success.
#
# 8. What is the binomial distribution, and how is it used in probability?
#  - The binomial distribution models the number of successes in
# n independent Bernoulli trials.
# Used in yes/no situations like coin tosses or pass/fail tests.
#
# 9. What is the Poisson distribution and where is it applied?
#  - The Poisson distribution models the number of events occurring in a fixed interval of time or space when events happen independently.
# Example: Number of emails received per hour.
#
# 10. What is a continuous uniform distribution?
#  - A continuous uniform distribution has equal probability for all values within a certain range.
# PDF is constant across the range.
#
# 11. What are the characteristics of a normal distribution?
#  - Symmetrical, bell-shaped curve.
#  - Mean = Median = Mode.
#  - Defined by mean (μ) and standard deviation (σ).
#  - 68-95-99.7 Rule applies.
#
# 12. What is the standard normal distribution, and why is it important?
#  - It is a normal distribution with mean = 0 and standard deviation = 1.
#  - Important for Z-score calculations and hypothesis testing.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in
# statistics?
#  - CLT states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population’s distribution.
#  - It's vital for making inferences about populations.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
#  - CLT justifies the use of the normal distribution for the sampling distribution of the mean, even when the population isn’t normally distributed.
#
# 15. What is the application of Z statistics in hypothesis testing?
#  - Z-statistics help determine whether to reject the null hypothesis by comparing the Z-score with critical values under the standard normal distribution.
#
# 16. How do you calculate a Z-score, and what does it represent?
#  -
# Z = (X - μ) / σ
# It shows how many standard deviations a value
# X is from the mean
# μ. Helps in comparing data across different scales.
#
# 17. What are point estimates and interval estimates in statistics?
#  - Point Estimate: A single value estimate of a parameter (e.g., sample mean).
#  - Interval Estimate: A range (confidence interval) that likely contains the population parameter.
#
# 18. What is the significance of confidence intervals in statistical analysis?
#  - They provide a range within which we expect the population parameter to lie with a certain level of confidence (e.g., 95%).
#
# 19. What is the relationship between a Z-score and a confidence interval?
#  - Z-scores determine the margin of error in confidence intervals.
#  - E.g., for 95% confidence, Z ≈ 1.96 is used.
#
# 20. How are Z-scores used to compare different distributions?
#  - Z-scores standardize different datasets, allowing comparison of values across different distributions by showing their position relative to their means.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
#  - Sample size is sufficiently large (typically
# 𝑛
# ≥
# 30
# n≥30).
#
#  - Samples are independent.
#
#  - Population has finite variance.
#
# 22. What is the concept of expected value in a probability distribution?
#  - It is the average value you expect from a random variable over many trials.
# Formula:
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E(X)=∑x
# i
# ​
#  ⋅P(x
# i
# ​
#  )
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#  - The shape and probabilities in the distribution determine the expected value, which represents the long-run average outcome of the random variable.
